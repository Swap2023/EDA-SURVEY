# %%
import pandas as pd

# %%
data=pd.read_csv(r"D:\STUDY\PYTHON\BIG DATA PRACTICE\9. Survey Dataset - Technical Interview.csv")

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
#Load the dataset into a pandas dataframe. Name the variable as “survey”.

# %%
survey=data.copy()

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
# How many samples were collected on each day?

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969

# %%
data['collection_date'].value_counts()
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
#What proportion of the total respondents were aged less than 45?

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969

# %%
data.age>45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13340\1725887641.py in <module>
# ----> 1 data.age>45
#
# ~\a\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~\a\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# ~\a\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5621
#    5622         with np.errstate(all="ignore"):
# -> 5623             res_values = ops.comparison_op(lvalues, rvalues, op)
# ...

# %%
data.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
data.age.replace({'24ko':24},inplace=True)

# %%
data.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '56', '50', '55', '54', '62', '60', '59', '47',
#        '61', '52', '66', '57', '67', '65', '71', '63', '64', '68', '69',
#        '99', '72', '75', '76'], dtype=object)

# %%
data.age>45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13340\1725887641.py in <module>
# ----> 1 data.age>45
#
# ~\a\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~\a\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# ~\a\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5621
#    5622         with np.errstate(all="ignore"):
# -> 5623             res_values = ops.comparison_op(lvalues, rvalues, op)
# ...

# %%
data.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                  object
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# dtype: object

# %%
data.age=data.age.astype(int)

# %%
data.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                   int32
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# dtype: object

# %%
data[data.age>45]
# Out:
#       response_id collection_date urban_rural          education  \
# 12             13       5-24-2017       Urban  Post - Graduation
# 33             34       5-24-2017       Urban           Graduate
# 59             60       5-24-2017       Rural          12th Pass
# 69             70       5-24-2017       Rural           Graduate
# 74             75       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6787         6788        6-1-2017       Rural          10th Pass
# 6804         6805        6-1-2017       Rural           Graduate
# 6810         6811        6-1-2017       Rural          12th Pass
# 6829         6830        6-1-2017       Urban           Graduate
# 6851         6852        6-1-2017       Urban           Graduate
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# 12     ₹ 5,000 - ₹ 10,000  Undecided     JD(U)  Somewhat Dissatisfied
# ...

# %%
#Create a new column in the dataframe “age_group”. This column should contain the age group the respondent belongs to. 
#The age groups are 18-25, 25-40, 40-55 and 55+. 
#The dataframe should look like this after the column creation

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969

# %%
data.insert(10,'Age_Group', data.age)

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
data1=data[(data.age>=18) & (data.age<25)]

# %%
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data2=data[(data.age>=25) & (data.age<40)]

# %%
data2
# Out:
#       response_id collection_date urban_rural          education  \
# 0               1       5-24-2017       Rural          12th Pass
# 1               2       5-24-2017       Rural           Graduate
# 3               4       5-24-2017       Urban           Graduate
# 5               6       5-24-2017       Urban           Graduate
# 6               7       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6852         6853        6-1-2017       Rural           Graduate
# 6854         6855        6-1-2017       Rural  Post - Graduation
# 6855         6856        6-1-2017       Rural          12th Pass
# 6863         6864        6-1-2017       Rural           Graduate
# 6866         6867        6-1-2017       Rural          10th Pass
#
#                    income   Vote_Now Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000        BJP       BJP  Fully Dissatisfied
# ...

# %%
data3=data[(data.age>=40) & (data.age<55)]

# %%
data3
# Out:
#       response_id collection_date urban_rural          education  \
# 11             12       5-24-2017       Urban           Graduate
# 12             13       5-24-2017       Urban  Post - Graduation
# 28             29       5-24-2017       Rural           Graduate
# 30             31       5-24-2017       Urban           Graduate
# 33             34       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6810         6811        6-1-2017       Rural          12th Pass
# 6812         6813        6-1-2017       Rural          10th Pass
# 6829         6830        6-1-2017       Urban           Graduate
# 6840         6841        6-1-2017       Rural           Graduate
# 6856         6857        6-1-2017       Rural  Post - Graduation
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# 11    ₹ 10,000 - ₹ 20,000        LJP     JD(U)     Somewhat Satisfied
# ...

# %%
data4=data[(data.age>55)]

# %%
data4
# Out:
#       response_id collection_date urban_rural               education  \
# 69             70       5-24-2017       Rural                Graduate
# 74             75       5-24-2017       Urban                Graduate
# 121           122       5-24-2017       Rural                Graduate
# 126           127       5-24-2017       Urban                Graduate
# 277           278       5-24-2017       Urban       Post - Graduation
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                      income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data1.Age_Group='18-25'
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_13340\1535017084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.Age_Group='18-25'

# %%
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data2.Age_Group='25-40'
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_13340\3185372014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.Age_Group='25-40'

# %%
data3.Age_Group='40-55'
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_13340\616217637.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.Age_Group='40-55'

# %%
data4.Age_Group='55+'
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_13340\2422690460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4.Age_Group='55+'

# %%
data4
# Out:
#       response_id collection_date urban_rural               education  \
# 69             70       5-24-2017       Rural                Graduate
# 74             75       5-24-2017       Urban                Graduate
# 121           122       5-24-2017       Rural                Graduate
# 126           127       5-24-2017       Urban                Graduate
# 277           278       5-24-2017       Urban       Post - Graduation
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                      income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
new=pd.concat([data1,data2,data3,data4])

# %%
new
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
#How many samples were collected for each age-group? Which age-group had the most samples?

# %%
new.Age_Group.value_counts()
# Out:
# 25-40    3844
# 18-25    2094
# 40-55     801
# 55+       108
# Name: Age_Group, dtype: int64

# %%
# What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions?

# %%
new.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age Age_Group  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22     18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505

# %%
new.Vote_Now.unique()
# Out:
# array(['JD(U)', 'BJP', 'RJD', 'JAP(L)', 'Others', 'NOTA', 'Plurals',
#        'BSP', 'RJJP', 'AAP', 'INC', 'LJP', 'RLSP', 'HAM', 'Undecided',
#        'VIP', 'Left Front', 'AIMIM'], dtype=object)

# %%
new[(new.Vote_Now=='RJD') & (new.Past_Vote=='RJD')]
# Out:
#       response_id collection_date urban_rural          education  \
# 16             17       5-24-2017       Rural  Post - Graduation
# 38             39       5-24-2017       Urban           Graduate
# 47             48       5-24-2017       Urban           Graduate
# 85             86       5-24-2017       Rural          12th Pass
# 120           121       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 3012         3013       5-29-2017       Urban  Post - Graduation
# 4753         4754       5-26-2017       Rural  Post - Graduation
# 5493         5494       5-26-2017       Urban           Graduate
# 5687         5688       5-29-2017       Urban           Graduate
# 5830         5831       5-30-2017       Urban           Graduate
#
#                    income Vote_Now Past_Vote        CM_satisfaction  \
# 16      BPL/Below ₹ 5,000      RJD       RJD     Fully Dissatisfied
# ...

# %%
# For each day of sample collection, determine the proportion of respondents who were fully satisfied with 
#the performance of the CM. So if there were a total of 1000 samples on day 1 and 300 out of those said they were
#fully satisfied, then our answer for that day would be 0.3

# %%
new.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age Age_Group  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22     18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505

# %%
new[new.CM_satisfaction=='Fully Satisfied']
# Out:
#       response_id collection_date urban_rural          education  \
# 4               5       5-24-2017       Rural           Graduate
# 8               9       5-24-2017       Urban          12th Pass
# 14             15       5-24-2017       Rural           Graduate
# 75             76       5-24-2017       Rural           Graduate
# 90             91       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 6341         6342       5-26-2017       Rural  Post - Graduation
# 6498         6499       5-28-2017       Urban  Post - Graduation
# 6513         6514       5-28-2017       Urban  Post - Graduation
# 6787         6788        6-1-2017       Rural          10th Pass
# 6851         6852        6-1-2017       Urban           Graduate
#
#                      income Vote_Now     Past_Vote  CM_satisfaction  \
# 4       ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote  Fully Satisfied
# ...

# %%
#In a similar fashion create a day-wise proportion of respondents that opted fully dissatisfied with
#their MLA. Create a line plot of the result with date on x-axis and proportions on the y-axis.

# %%
new.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age Age_Group  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22     18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505

# %%
new[new.MLA_satisfaction=='Fully Dissatisfied']
# Out:
#       response_id collection_date urban_rural               education  \
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 18             19       5-24-2017       Rural                Graduate
# 45             46       5-24-2017       Rural                Graduate
# 47             48       5-24-2017       Urban                Graduate
# ...           ...             ...         ...                     ...
# 6123         6124       5-24-2017       Urban  Professional Education
# 6262         6263       5-25-2017       Urban                Graduate
# 6268         6269       5-25-2017       Rural                Graduate
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
#
#                    income Vote_Now Past_Vote        CM_satisfaction  \
# ...

# %%
new.MLA_satisfaction.unique()
# Out:
# array(['Fully Satisfied', 'Fully Dissatisfied', 'Somewhat Satisfied',
#        'Can’t say', 'Somewhat Dissatisfied'], dtype=object)

# %%
#Create a dataframe by performing a group by over age_group and calculate the count of total samples under each age_group

# %%
new.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age Age_Group  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22     18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505

# %%
data.groupby('Age_Group').count()
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# Age_Group
# 18                 125              125          125        125     125
# 19                 171              171          171        171     171
# 20                 328              328          328        328     328
# 21                 311              311          311        311     311
# 22                 392              392          392        392     392
# 23                 317              317          317        317     317
# 24                 450              450          450        450     450
# 25                 598              598          598        598     598
# 26                 389              389          389        389     389
# 27                 360              360          360        360     360
# 28                 396              396          396        396     396
# 29                 239              239          239        239     239
# ...
